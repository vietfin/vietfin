# %% [markdown]
# # Financial statements
#
# VietFin provides access to financial statements as quarterly or annual.
#
# Financial statement functions are grouped under the `vf.equity.fundamental` class.
#
# The typical financial statements consist of three endpoints:
#
# - Balance Sheet: `vf.equity.fundamental.balance()`
# - Income Statement: `vf.equity.fundamental.income()`
# - Cash Flow Statement: `vf.equity.fundamental.cash()`
#
# The main parameters are:
#
# - `symbol`: The company's ticker symbol.
# - `period`: 'annual' or 'quarter'. Default is 'annual'.
#
# However:
#
# - Every data provider has their own way of parsing and organizing the three financial statements.
# - Items within each statement will vary by source.
# - Names of line items will also vary by source.
#
# This example will try to highlight how different providers have different labels and values for a company's facts.

# %%
from vietfin import vf
import pandas as pd

compare = pd.DataFrame()

# Collect all of the line item "total assets" in Balance Sheet of company "ACB" from provider "tcbs"
tcbs = vf.equity.fundamental.balance(symbol="acb", period="annual", provider="tcbs").to_df()
tcbs = tcbs.query('items.str.contains("TOTAL ASSETS", case=False)')
tcbs = tcbs.set_index("fiscal_year")
compare["tcbs"] = tcbs["values"]

# Do similar thing with "ssi" as provider
ssi = vf.equity.fundamental.balance(symbol="acb", period="annual", provider="ssi").to_df()
ssi = ssi.query('items.str.contains("TOTAL ASSETS", case=False)')
ssi['fiscal_period'] = ssi['fiscal_period'].astype(int)
ssi = ssi.set_index("fiscal_period")
compare["ssi"] = ssi["values"]

compare
# Out:
# Retrieved 748 data point for balancesheet, of stock ticker ACB.
# Retrieved 1 records for equity.search() from SSI.
# Retrieved 1056 data point for BalanceSheet, of stock ticker ACB.
#                  tcbs           ssi
# fiscal_year
# 2023         718795.0  7.187946e+14
# 2022         607875.0  6.078752e+14
# 2021         527770.0  5.277699e+14
# 2020         444530.0  4.445301e+14
# 2019         383514.0  3.835144e+14
# 2018         329333.0  3.293332e+14
# 2017         284316.0  2.843161e+14
# 2016         233681.0  2.336809e+14
# 2015         201457.0  2.014570e+14
# 2014         179610.0  1.796098e+14
# 2013         166599.0  1.665990e+14
# 2012         176308.0  1.763076e+14
# 2011         281019.0  2.810193e+14
# 2010         205103.0  2.051030e+14
# 2009         167881.0  1.678810e+14
# 2008         105306.0  1.053061e+14
# 2007          85392.0  8.539168e+13
# 2006          44650.0  4.465019e+13
# 2005          24273.0  2.427286e+13
# 2004          15420.0  1.541953e+13
# 2003          10855.0  1.085480e+13
# 2002           9350.0  9.349660e+12

# %% [markdown]
# Next, let's see how each provider organize the line items in the financial statement for each fiscal period.

# %%
# Collect all the line items in Balance Sheet of company "ACB" for fiscal_year 2022 from provider "tcbs"
tcbs = vf.equity.fundamental.balance(symbol="acb", period="annual", provider="tcbs").to_df()
tcbs = tcbs.query('fiscal_year == 2022').reset_index(drop=True)
tcbs
# Out:
# Retrieved 748 data point for balancesheet, of stock ticker ACB.
#     fiscal_year  fiscal_quarter  period symbol                      items  \
# 0          2022               5  annual    ACB                 shortAsset
# 1          2022               5  annual    ACB  cash and cash equivalents
# 2          2022               5  annual    ACB                shortInvest
# 3          2022               5  annual    ACB            shortReceivable
# 4          2022               5  annual    ACB                  inventory
# 5          2022               5  annual    ACB                  longAsset
# 6          2022               5  annual    ACB                 fixedAsset
# 7          2022               5  annual    ACB               total assets
# 8          2022               5  annual    ACB                 total debt
# 9          2022               5  annual    ACB                  shortDebt
# 10         2022               5  annual    ACB                   longDebt
# 11         2022               5  annual    ACB               total equity
# 12         2022               5  annual    ACB                    capital
# 13         2022               5  annual    ACB         centralBankDeposit
# 14         2022               5  annual    ACB           otherBankDeposit
# 15         2022               5  annual    ACB              otherBankLoan
# 16         2022               5  annual    ACB                stockInvest
# 17         2022               5  annual    ACB               customerLoan
# 18         2022               5  annual    ACB                    badLoan
# 19         2022               5  annual    ACB                  provision
# 20         2022               5  annual    ACB            netCustomerLoan
# 21         2022               5  annual    ACB                 otherAsset
# 22         2022               5  annual    ACB            otherBankCredit
# 23         2022               5  annual    ACB               oweOtherBank
# 24         2022               5  annual    ACB             oweCentralBank
# 25         2022               5  annual    ACB              valuablePaper
# 26         2022               5  annual    ACB            payableInterest
# 27         2022               5  annual    ACB         receivableInterest
# 28         2022               5  annual    ACB                    deposit
# 29         2022               5  annual    ACB                  otherDebt
# 30         2022               5  annual    ACB                       fund
# 31         2022               5  annual    ACB        unDistributedIncome
# 32         2022               5  annual    ACB     minorShareHolderProfit
# 33         2022               5  annual    ACB                    payable
#
#       values
# 0        NaN
# 1     8461.0
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6     3981.0
# 7   607875.0
# 8   549437.0
# 9        NaN
# 10       NaN
# 11   58439.0
# 12   33774.0
# 13   13658.0
# 14   82339.0
# 15    3683.0
# 16   76813.0
# 17  413706.0
# 18    3045.0
# 19   -4850.0
# 20  408857.0
# 21    9858.0
# 22   60003.0
# 23    7838.0
# 24     506.0
# 25   44304.0
# 26    5564.0
# 27    4090.0
# 28  413953.0
# 29   22772.0
# 30    9220.0
# 31   15172.0
# 32       0.0
# 33  549437.0

# %%
# Collect all of the line items in Balance Sheet of company "ACB" for fiscal_year 2022 from provider "ssi"
ssi = vf.equity.fundamental.balance(symbol="acb", period="annual", provider="ssi").to_df()
ssi['fiscal_period'] = ssi['fiscal_period'].astype(int)
ssi = ssi.query('fiscal_period == 2022').reset_index(drop=True)
ssi
# Out:
# Retrieved 1 records for equity.search() from SSI.
# Retrieved 1056 data point for BalanceSheet, of stock ticker ACB.
#     fiscal_period  period                                              items  \
# 0            2022  annual                                       TOTAL ASSETS
# 1            2022  annual                           Cash and precious metals
# 2            2022  annual                              Balances with the SBV
# 3            2022  annual           Placements & loan to credit institutions
# 4            2022  annual                            Trading securities, net
# 5            2022  annual                                 Trading securities
# 6            2022  annual  Less: Provision for diminution in value of tra...
# 7            2022  annual             Derivatives and other financial assets
# 8            2022  annual               Loans and advances to customers, net
# 9            2022  annual                    Loans and advances to customers
# 10           2022  annual  Less: Provision for losses on loans and advanc...
# 11           2022  annual                              Investment Securities
# 12           2022  annual                     Available-for-sales securities
# 13           2022  annual                        Held-to-maturity securities
# 14           2022  annual  Less: Provision for diminution in value of inv...
# 15           2022  annual  Investment in other entities and long term inv...
# 16           2022  annual                       Investment in Joint Ventures
# 17           2022  annual                  Investment in associate companies
# 18           2022  annual                        Other Long-term investments
# 19           2022  annual                Provision for long-term investments
# 20           2022  annual                                       Fixed assets
# 21           2022  annual                              Tangible fixed assets
# 22           2022  annual                              Finance leased assets
# 23           2022  annual                            Intangible fixed assets
# 24           2022  annual                                Bất động sản đầu tư
# 25           2022  annual                                    Tài sản Có khác
# 26           2022  annual               LIABILITIES AND SHAREHOLDER'S EQUITY
# 27           2022  annual                                  Total liabilities
# 28           2022  annual                 Due to Gov and borrowings from SBV
# 29           2022  annual  Deposits and borrowings from other credit inst...
# 30           2022  annual                            Deposits from customers
# 31           2022  annual        Derivatives and other financial liabilities
# 32           2022  annual  Funds received from Gov, international and oth...
# 33           2022  annual  Convertible bonds/CDs and other valuable paper...
# 34           2022  annual                                  Other liabilities
# 35           2022  annual                               Shareholders' Equity
# 36           2022  annual                                            Capital
# 37           2022  annual                                    Charter capital
# 38           2022  annual                        Fund for basic construction
# 39           2022  annual                                      Share premium
# 40           2022  annual                                    Treasury shares
# 41           2022  annual                                   Preferred shares
# 42           2022  annual                                     Other capitals
# 43           2022  annual                                           Reserves
# 44           2022  annual                Foreign currency difference reserve
# 45           2022  annual                 Difference upon assets revaluation
# 46           2022  annual                                  Retained Earnings
# 47           2022  annual                                  Minority interest
#
#           values
# 0   6.078752e+14
# 1   8.460892e+12
# 2   1.365753e+13
# 3   8.597131e+13
# 4   1.131327e+12
# 5   1.320941e+12
# 6  -1.896140e+11
# 7   1.000720e+11
# 8   4.088565e+14
# 9   4.137062e+14
# 10 -4.849736e+12
# 11  7.553479e+13
# 12  3.185492e+13
# 13  4.367988e+13
# 14  0.000000e+00
# 15  1.468140e+11
# 16  0.000000e+00
# 17  0.000000e+00
# 18  3.033870e+11
# 19 -1.565730e+11
# 20  3.981376e+12
# 21  2.849732e+12
# 22  0.000000e+00
# 23  1.131644e+12
# 24  1.770050e+11
# 25  9.857553e+12
# 26  6.078752e+14
# 27  5.494365e+14
# 28  5.058760e+11
# 29  6.784084e+13
# 30  4.139528e+14
# 31  0.000000e+00
# 32  6.018800e+10
# 33  4.430437e+13
# 34  2.277246e+13
# 35  5.843866e+13
# 36  3.404613e+13
# 37  3.377435e+13
# 38  0.000000e+00
# 39  2.717790e+11
# 40  0.000000e+00
# 41  0.000000e+00
# 42  0.000000e+00
# 43  9.220125e+12
# 44  0.000000e+00
# 45  0.000000e+00
# 46  1.517241e+13
# 47  0.000000e+00
