# %%
# %xmode Verbose

from vietfin import vf

#vf.funds.search().to_df().head(5)
#vf.funds.search(symbol='vesaf').to_df()
#vf.funds.search(provider='asdf')
print(vf.funds.search().results)
# Out:
# Exception reporting mode: Verbose
# ...

# %%
vf.funds.historical("vff").to_df()
# Out:
#             nav_per_share  fund_id
# date
# 2017-01-10       13284.00       21
# 2017-01-17       13294.00       21
# 2017-01-24       13341.00       21
# 2017-01-31       13357.00       21
# 2017-01-31       13359.00       21
# ...                   ...      ...
# 2024-01-04       22314.99       21
# 2024-01-09       22335.89       21
# 2024-01-11       22344.94       21
# 2024-01-16       22399.95       21
# 2024-01-18       22406.89       21
#
# [507 rows x 2 columns]

# %%
vf.funds.holdings("vibf").to_df()
# Out:
#   stock_code                industry  net_asset_percent type_asset  \
# 0        FPT  Công nghệ và thông tin               7.13      STOCK
# 1        MBB               Ngân hàng               6.27      STOCK
# 2        ACB               Ngân hàng               3.91      STOCK
# 3        VCB               Ngân hàng               3.79      STOCK
# 4        PNJ        Sản xuất Phụ trợ               3.62      STOCK
# 5        PVD             Khai khoáng               3.33      STOCK
# 6        TCB               Ngân hàng               2.95      STOCK
# 7   KDH12202            Bất động sản               8.40       BOND
# 8  TN1122016            Bất động sản               5.88       BOND
# 9  BAF122029        Nông - Lâm - Ngư               4.81       BOND
#
#                          update_at
# 0 2024-01-09 03:46:13.762000+00:00
# 1 2024-01-09 03:46:13.762000+00:00
# 2 2024-01-09 03:46:13.762000+00:00
# 3 2024-01-09 03:46:13.762000+00:00
# 4 2024-01-09 03:46:13.762000+00:00
# ...
